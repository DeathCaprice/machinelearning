# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import joblib
from tensorflow.keras.models import load_model

# ダミーデータの生成
np.random.seed(42)
data = {
    'feature1': np.random.rand(100),
    'feature2': np.random.rand(100),
    'feature3': np.random.rand(100),
    'feature4': np.random.rand(100),
    'accident': np.random.randint(0, 2, 100)
}

df = pd.DataFrame(data)
df.to_csv('accident_data.csv', index=False)

# データの読み込み
data = pd.read_csv('accident_data.csv')

# 特徴量とターゲットの分割
X = data.drop('accident', axis=1)
y = data['accident']

# データの標準化
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 訓練データとテストデータに分割
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# モデルの構築
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# モデルのコンパイル
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# モデルの訓練
model.fit(X_train, y_train, epochs=50, batch_size=10, validation_data=(X_test, y_test))

# モデルとスケーラーの保存
model.save('accident_model.h5')
joblib.dump(scaler, 'scaler.pkl')

def predict_accident(input_data):
    # モデルとスケーラーの読み込み
    model = load_model('accident_model.h5')
    scaler = joblib.load('scaler.pkl')

    # 入力データの標準化
    input_data_scaled = scaler.transform(input_data)

    # 予測
    prediction = model.predict(input_data_scaled)
    return prediction
# Out:
# Epoch 1/50
# 8/8 [==============================] - 1s 25ms/step - loss: 0.7269 - accuracy: 0.4500 - val_loss: 0.7578 - val_accuracy: 0.4500
# Epoch 2/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6940 - accuracy: 0.4875 - val_loss: 0.7373 - val_accuracy: 0.3500
# Epoch 3/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6774 - accuracy: 0.5625 - val_loss: 0.7206 - val_accuracy: 0.4500
# Epoch 4/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6645 - accuracy: 0.5875 - val_loss: 0.7135 - val_accuracy: 0.4500
# Epoch 5/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6524 - accuracy: 0.6125 - val_loss: 0.7082 - val_accuracy: 0.4500
# Epoch 6/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6452 - accuracy: 0.6500 - val_loss: 0.7128 - val_accuracy: 0.5000
# Epoch 7/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6374 - accuracy: 0.6500 - val_loss: 0.7143 - val_accuracy: 0.5000
# Epoch 8/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6283 - accuracy: 0.6625 - val_loss: 0.7216 - val_accuracy: 0.5000
# Epoch 9/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.6222 - accuracy: 0.6625 - val_loss: 0.7265 - val_accuracy: 0.5500
# Epoch 10/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6161 - accuracy: 0.6625 - val_loss: 0.7315 - val_accuracy: 0.5500
# Epoch 11/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.6102 - accuracy: 0.6625 - val_loss: 0.7384 - val_accuracy: 0.5500
# Epoch 12/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.6045 - accuracy: 0.6750 - val_loss: 0.7442 - val_accuracy: 0.5500
# Epoch 13/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5993 - accuracy: 0.6750 - val_loss: 0.7508 - val_accuracy: 0.5500
# Epoch 14/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5941 - accuracy: 0.6875 - val_loss: 0.7542 - val_accuracy: 0.5500
# Epoch 15/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5906 - accuracy: 0.6750 - val_loss: 0.7635 - val_accuracy: 0.5500
# Epoch 16/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5841 - accuracy: 0.6875 - val_loss: 0.7704 - val_accuracy: 0.5500
# Epoch 17/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5793 - accuracy: 0.6875 - val_loss: 0.7747 - val_accuracy: 0.5500
# Epoch 18/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5756 - accuracy: 0.7000 - val_loss: 0.7750 - val_accuracy: 0.5500
# Epoch 19/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5712 - accuracy: 0.7000 - val_loss: 0.7861 - val_accuracy: 0.5500
# Epoch 20/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5667 - accuracy: 0.7000 - val_loss: 0.7900 - val_accuracy: 0.5500
# Epoch 21/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5622 - accuracy: 0.7000 - val_loss: 0.7959 - val_accuracy: 0.5500
# Epoch 22/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5582 - accuracy: 0.7000 - val_loss: 0.7983 - val_accuracy: 0.5500
# Epoch 23/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5543 - accuracy: 0.7000 - val_loss: 0.8042 - val_accuracy: 0.5500
# Epoch 24/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5503 - accuracy: 0.7000 - val_loss: 0.8096 - val_accuracy: 0.5000
# Epoch 25/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5470 - accuracy: 0.7000 - val_loss: 0.8197 - val_accuracy: 0.5000
# Epoch 26/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5432 - accuracy: 0.7125 - val_loss: 0.8149 - val_accuracy: 0.5000
# Epoch 27/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5407 - accuracy: 0.7125 - val_loss: 0.8143 - val_accuracy: 0.5500
# Epoch 28/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5372 - accuracy: 0.7125 - val_loss: 0.8250 - val_accuracy: 0.5000
# Epoch 29/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5310 - accuracy: 0.7250 - val_loss: 0.8278 - val_accuracy: 0.5000
# Epoch 30/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5275 - accuracy: 0.7375 - val_loss: 0.8354 - val_accuracy: 0.5000
# Epoch 31/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.5237 - accuracy: 0.7375 - val_loss: 0.8405 - val_accuracy: 0.5000
# Epoch 32/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.5197 - accuracy: 0.7250 - val_loss: 0.8459 - val_accuracy: 0.5000
# Epoch 33/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5167 - accuracy: 0.7375 - val_loss: 0.8420 - val_accuracy: 0.5000
# Epoch 34/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5126 - accuracy: 0.7500 - val_loss: 0.8489 - val_accuracy: 0.5000
# Epoch 35/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.5085 - accuracy: 0.7500 - val_loss: 0.8448 - val_accuracy: 0.5000
# Epoch 36/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5042 - accuracy: 0.7500 - val_loss: 0.8574 - val_accuracy: 0.5500
# Epoch 37/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.5010 - accuracy: 0.7625 - val_loss: 0.8637 - val_accuracy: 0.5500
# Epoch 38/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4963 - accuracy: 0.7625 - val_loss: 0.8586 - val_accuracy: 0.5500
# Epoch 39/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4926 - accuracy: 0.7625 - val_loss: 0.8581 - val_accuracy: 0.5500
# Epoch 40/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4879 - accuracy: 0.7750 - val_loss: 0.8611 - val_accuracy: 0.6000
# Epoch 41/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4846 - accuracy: 0.7750 - val_loss: 0.8704 - val_accuracy: 0.5000
# Epoch 42/50
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4787 - accuracy: 0.7750 - val_loss: 0.8735 - val_accuracy: 0.5000
# Epoch 43/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4744 - accuracy: 0.7875 - val_loss: 0.8822 - val_accuracy: 0.5000
# Epoch 44/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4705 - accuracy: 0.7875 - val_loss: 0.8874 - val_accuracy: 0.5000
# Epoch 45/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4659 - accuracy: 0.7875 - val_loss: 0.8890 - val_accuracy: 0.5000
# Epoch 46/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4618 - accuracy: 0.7875 - val_loss: 0.8801 - val_accuracy: 0.6000
# Epoch 47/50
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4571 - accuracy: 0.7875 - val_loss: 0.8969 - val_accuracy: 0.5000
# Epoch 48/50
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4519 - accuracy: 0.7875 - val_loss: 0.9006 - val_accuracy: 0.5000
# Epoch 49/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.4478 - accuracy: 0.7875 - val_loss: 0.9142 - val_accuracy: 0.4500
# Epoch 50/50
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4449 - accuracy: 0.7875 - val_loss: 0.9098 - val_accuracy: 0.5000
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
